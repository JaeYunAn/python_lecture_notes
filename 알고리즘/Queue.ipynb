# %% [markdown]
# # Queue

# %% [markdown]
# # 큐

# %% [markdown]
# 큐
# - 먼저 들어온 데이터가 먼저 나가는 선형 자료 구조

# %% [markdown]
# 선입선출(FIFO)
# - 가장 먼저 넣은 자료가 가장 먼저 나오는 것

# %% [markdown]
# 큐의 구조
# - 머리(Front): 저장된 원소 중 첫 번째 원소(또는 삭제된 위치)
# - 꼬리(Rear): 저장된 원소 중 마지막 원소

# %% [markdown]
# 큐의 기본 연산
# - 삽입: enqueue
# - 삭제: dequeue

# %% [markdown]
# 연산 목록
# - enqueue(item): 큐의 뒤쪽(rear 다음)에 원소를 삽입
# - dequeue(): 큐의 앞쪽(front)에서 원소를 삭제하고 반환
# - create_queue(): 공백 상태의 큐를 생성
# - is_empty(): 큐가 공백 상태인지를 확인
# - is_full(): 큐가 포화 상태인지를 확인
# - qpeek(): 큐의 앞쪽(fornt)에서 원소를 삭제 없이 반환

# %% [markdown]
# 큐의 연산 과정
# - 1. 공백 큐 생성: create_queue()
#   - front = -1
#   - rear = -1
# - 2. 원소 A 삽입: enqueue(A)
#   - front = -1
#   - rear = 0 (A의 위치)
# - 3. 원소 B 삽입: enqueue(B)
#   - front = -1
#   - rear = 1 (B의 위치)
# - 4. 원소 반환 / 삭제: dequeue()
#   - A가 삭제됨
#   - front = 0 (A가 있었던 위치)
#   - rear = 1 (B의 위치)
# - 5. 원소 C 삽입: enqueue(C)
#   - front = 0
#   - rear = 2 (C의 위치)
# - 6. 원소 반환 / 삭제: dequeue()
#   - B가 삭제됨
#   - front = 1 (B가 있던 위치)
#   - rear = 2 (C의 위치)
# - 7. 원소 반환 / 삭제: dequeue()
#   - C가 삭제됨
#   - front = 2 (C가 있던 위치)
#   - rear = 2 (C가 있던 위치): 더 뒤에 들어온 원소가 없으니 마지막에 들어온 C자리 그대로 유지

# %% [markdown]
# # 선형 큐

# %% [markdown]
# 선형 큐
# - 데이터를 일렬로 저장하며, 앞에서 꺼내고 뒤에 넣는 기본 큐 구조

# %% [markdown]
# 선형 큐
# - 구현
#   - 배열이나 연결 리스트로 구현 가능
#   - 배열로 구현한 경우 큐의 크기는 배열의 크기와 같다
#   - front: 가장 최근에 삭제된 원소의 인덱스
#   - rear: 마지막으로 저장된 원소의 인덱스
#
# - 상태 표현
#   - 초기 상태: front = rear = -1
#   - 공백 상태: front == rear
#   - 포화 상태: rear == n - 1
#     - n: 배열의 크기
#     - n - 1: 크기가 n인 배열의 마지막 인덱스

# %% [markdown]
# # 선형 큐의 구현

# %% [markdown]
# 1. 초기 공백 큐 생성: create_queue()
#   - 크기 n인 1차원 배열 생성
#   - front와 rear를 -1로 초기화

# %%
# create_queue()에 해당
q = [0] * n
front = -1
rear = -1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # create_queue()에 해당
# ----> 2 q = [0] * n
#       3 front = -1
#       4 rear = -1
#
# NameError: name 'n' is not defined

# %% [markdown]
# 2. 삽입: enqueue(item)
# - 마지막 원소 뒤에 새로운 원소를 삽입하기 위해
#   - 1. rear값을 하나 증가시켜 새로운 원소를 삽입할 자리를 지정
#   - 2. 그 인덱스에 해당하는 배열 원소 q[rear]에 item을 저장

# %%
def enqueue(item):
    global rear
    if is_full():
        print("Queue_Full")
    else:
        rear += 1
        q[rear] = item

# %% [markdown]
# 3. 삭제: dequeue()
# - 가장 앞에 있는 원소를 삭제하기 위해
#   - 1. front값을 하나 증가시켜 큐에 남아 있는 첫 번째 원소로 이동
#   - 2. 첫 번째 원소를 반환함으로써 삭제와 동일한 기능을 함

# %%
def dequeue():
    global front
    if is_empty():
        print('Queue_Empty')
    else:
        front += 1
        return q[front]
# Out:
#   Cell In[2], line 1
#     def dequeue():
#                   ^
# SyntaxError: incomplete input

# %% [markdown]
# 4. 공백 상태 및 포화 상태 검사: is_empty(), is_full()
# - 공백 상태: front == rear
# - 포화 상태: rear == n - 1
#   - n: 배열의 크기
#   - n - 1: 배열의 마지막 인덱스

# %%
def is_empty():
    return front == rear
def is_full():
    return rear == len(q) - 1

# %% [markdown]
# 5. 검색: qpeek()
# - 가장 앞에 있는 원소를 검색하여 반환하는 연산
# - 현재 front의 한 자리 뒤 (front + 1)에 있는 원소, 즉 큐의 첫 번째에 있는 원소를 반환

# %%
def peek():
    if is_empty():
        print('Queue_Empty')
    else:
        return q[front + 1]

# %% [markdown]
# # 원형 큐

# %% [markdown]
# 선형 큐 사용시 문제점
# - 잘못된 포화 상태 인식
#   - 선형 큐를 이용하여 원소의 삽입과 삭제를 계속할 경우, 배열의 앞 부분에 활용할 수 있는 공간이 있음에도 불구하고, rear == n - 1인 상태 즉, 포화상태로 인식하여 더 이상의 삽입을 수행하지 않게 됩니다.

# %% [markdown]
# 해결 방법 1
# - 매 연산이 이루어 질 떄 마다 저장된 원소들을 배열의 앞부분으로 모두 이동
# - 그러나, 이 방법은 원소 이동에 많은 시간이 소요되어 큐의 효율성이 급격히 떨어짐

# %% [markdown]
# 해결 방법 2
# - 1차원 배열을 이용
#   - 논리적으로는 배열의 처음과 끝이 연결되어 원형 형태를 이룬다고 가정하고 사용

# %% [markdown]
# # 원형 큐

# %% [markdown]
# 원형 큐
# - 선형 큐의 공간 낭비를 막기 위해 처음과 끝이 연결된 구조

# %% [markdown]
# 원형 큐의 구조
# - 초기 공백 상태
#   - front = rear = 0
#
# - Index의 순환
#   - front 또는 rear의 위치가 배열의 마지막 인덱스인 n - 1을 가리킴
#   - 그 다음에는 논리적 순환을 이루어 배열의 처음 인덱스인 0으로 이동
#   - 이를 위해 나머지 연산자(%)를 사용
#
# - front 변수
#   - 공백 상태와 포화 상태 구분을 쉽게 하기 위해 front가 있는 자리는 사용하지 않고 항상 빈 자리로 둠

# %% [markdown]
# 선형 큐와 원형 큐 비교
# - 삽입 위치 및 삭제 위치
#   - 선형 큐
#     - 삽입 위치: rear += 1
#     - 삭제 위치: front += 1
#
#   - 원형 큐
#     - 삽입 위치: rear = (rear + 1) mod n
#     - 삭제 위치: front = (front + 1) mod n

# %% [markdown]
# 원형 큐의 연산 과정
# - 1. create_Queue()
#   - front = 0
#   - rear = 0
# - 2. enqueue(A)
#   - front = 0
#   - rear = 1
# - 3. enqueue(B)
#   - front = 0
#   - rear = 2
# - 4. dequeue()
#   - front = 1
#   - rear = 2
# - 5. enqueue(C)
#   - front = 1
#   - rear = 3
# - 6. enqueue(D)
#   - front = 1
#   - rear = 0

# %% [markdown]
# # 원형 큐의 구현

# %% [markdown]
# 1. 초기 공백 큐 생성: create_queue()
# - 크기가 n인 1차원 배열 생성
# - front와 rear를 0으로 초기화

# %%
cq = [0] * n
front = 0
rear = 0

# %% [markdown]
# 2. 삽입: enqueue(item)
# - 마지막 원소 뒤에 새로운 원소를 삽입하기 위해
#   - 1. rear값을 조정하여 새로운 원소를 삽입할 자리를 지정
#     - rear <- (rear + 1) mode n
#   - 2. 그 인덱스에 해당하는 배열 원소 cq[rear]에 item을 저장

# %%
def enqueue(item):
    global rear
    if is_full():
        print('Queue_Full')
    else:
        rear = (rear + 1) % len(cq)
        cq[rear] = item

# %% [markdown]
# 3. 삭제: dequeue()
# - 가장 앞에 있는 원소를 삭제하기 위해
#   - 1. front값을 조정하여 삭제할 자리를 지정
#     - front <- (front + 1) mod n
#   - 2. 새로운 front원소를 반환함으로써 삭제와 동일한 기능을 함

# %%
def dequeue():
    global front
    if is_empty():
        print('Queue_Empty')
    else:
        front = (front + 1) % len(cq)
        return cq[front]

# %% [markdown]
# 4. 공백상태 및 포화상태 검사: is_empty(), is_full()
# - 공백 상태: front == rear
# - 포화 상태: 삽입할 rear의 다음 위치 == 현재 front
#   - (rear + 1) mod n == front

# %%
def is_empty():
    return front == rear

def is_full():
    return (rear + 1) % len(cq) == front

# %% [markdown]
# # 연결 큐

# %% [markdown]
# 연결 큐 (Linked Queue)
# - 연결 리스트를 이용해 구현한 큐

# %% [markdown]
# 연결 큐의 구조
# - 단순 연결 리스트(Linked List)를 이용한 큐
#   - 큐의 원소: 단순 연결 리스트의 노드
#   - 큐의 원소 순서: 노드의 연결 순서, 링크로 연결되어 있음
#   - front: 첫 번째 노드를 가리키는 링크
#   - rear: 마지막 노드를 가리키는 링크
# - 상태 표현
#   - 초기 상태: front == rear == NULL
#   - 공백 상태: front == rear == NULL

# %% [markdown]
# deque(덱)
# - 컨테이너 자료형 중 하나로 양쪽 끝에서 빠르게 추가와 삭제를 할 수 있는 리스트류 컨테이너
#   - 연결 리스트를 직접 만들지 않아도 된다.

# %% [markdown]
# deque의 연산
# - append(x): 오른쪽에 x추가
# - popleft(): 왼쪽에서 요소를 제거하고 반환, 요소가 없으면 IndexError

# %%
from collections import deque

q = deque()
q.append(i)     # enqueue()
t = q.popleft() # dequeue()

# %% [markdown]
# # 우선순위 큐

# %% [markdown]
# 우선순위 큐 (Priority Queue)
# - 우선순위를 가진 항목들을 저장하는 큐
#   - FIFO 순서가 아니라 우선순위가 높은 순서대로 먼저 나가게 됩니다.
#   - 우선순위 큐의 적용 분야로 시뮬레이션 시스템, 네트워크 트래픽 제어, 운영체제의 태스크 스케줄링이 있다.

# %% [markdown]
# 우선순위 큐의 연산
# - 삽입: enqueue
# - 삭제: dequeue

# %% [markdown]
# 배열을 이용한 우선순위 큐
# - 배열을 이용하여 자료를 저장
# - 원소를 삽입하는 과정에서 우선순위를 비교하여 적절한 위치에 삽입하는 구조
# - 가장 앞에 최고 우선순위의 원소가 위치함
# - 문제점
#   - 배열을 사용하므로, 삽입이나 삭제 연산이 일어날 때 원소의 재배치가 발생
#   - 이에 소요되는 시간이나 메모리 낭비가 큼

# %% [markdown]
# 효율적인 우선순위 큐
# - 트리 구조인 (Heap) 이용
# - 트리 단원에서 기본 원리를 배움

# %% [markdown]
# # 큐의 활용

# %% [markdown]
# # 버퍼

# %% [markdown]
# 버퍼(Buffer)
# - 데이터를 한 곳에서 다른 한 곳으로 전송하는 동안 일시적으로 그 데이터를 보관하는 메모리의 영역
#   - 버퍼를 채우는 것을 버퍼링이라고 한다.

# %% [markdown]
# 버퍼의 자료 구조
# - 버퍼는 일반적으로 입출력 및 네트워크와 관련된 기능에서 이용
# - 순서대로 입력 / 출력 / 전달되어야 하므로 FIFO 방식의 자료구조인 큐가 활용

# %% [markdown]
# # BFS

# %% [markdown]
# 그래프를 탐색하는 방법
# - 너비 우선 탐색: BFS
# - 깊이 우선 탐색: DFS

# %% [markdown]
# 너비 우선 탐색
# - 탐색 시작 정점에 인접한 정점들을 모두 차례로 방문한 후에, 방문했던 정점을 시작점으로 하여 다시 인접한 정점들을 차례로 방문하는 방식
#   - 인접한 정점들에 대해 탐색을 한 후, 차례로 다시 너비 우선 탐색을 진행해야 하므로, 선입선출 형태의 자료구조인 큐를 활용한다.
