# %% [markdown]
# ** 클래스
#
# * 클래스는 관련된 데이터(속성)와 기능(메서드)을 하나의 '묶음'으로 정의하는 설계도
# * 클래스 이름은 파스칼 케이스로 작성

# %% [markdown]
# ** 클래스 예시
#
# * __init__메서드는 '생성자 메서드'로 불림
# * 새로운 객체를 만들 때 필요한 초기값을 설정

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def introduce(self):
        print(f'안녕하세요. 저는 {self.name}, 나이는 {self.age}살입니다.')

# %% [markdown]
# ** 인스턴스
#
# * 클래스를 통해 생성된 객체

# %% [markdown]
# ** 인스턴스 예시
#
# * 클래스가 설계도라면, 인스턴스는 그 설계도로부터 실제 만들어진 '개별 물건'
# * Person('Alice', 25)라고 하면 Person이라는 설계도로부터 이름이 Alice이고 나이가 25인 '사람 객체'가 탄생

# %% [markdown]
# ** 클래스와 인스턴스
#
# * 클래스를 정의한다는 것은 공통된 특성과 기능을 가진 틀을 만드는 것
# * 실제 활동하는 개별 객체들은 이 틀에서 생성된 인스턴스
# * 공통된 특성과 기능을 가진 틀을 만드는 것은 곧 새로운 타입을 만드는 행위
#  * '아이유는 인스턴스다' 라는 표현은 모호한것이다.
#  * '무슨 타입의 인스턴스'인지 알 수 없기 때문이다.

# %% [markdown]
# ** 클래스 구조
#
# * 생성자 메서드
#  * 인스턴스 생성 시 자동 호출되는 특별한 메서드
#  * __init__이라는 이름의 메서드로 정의
#  * 인스턴스 변수의 초기화 담당

# %% [markdown]
# * 인스턴스 변수(속성)
#  * 각 인스턴스별 고유한 속성
#  * self.변수명 형태로 정의
#  * 인스턴스마다 독립적인 값 유지

# %% [markdown]
# * 클래스 변수(속성)
#  * 모든 인스턴스가 공유하는 속성
#  * 클래스 내부에서 직접 정의

# %% [markdown]
# ** 메서드 종류
#
# * 인스턴스 메서드
# * 클래스 메서드
# * 스태틱 메서드

# %% [markdown]
# 인스턴스 메서드
#
# * 인스턴스의 상태를 조작하거나 동작을 수행한다.

# %% [markdown]
# 인스턴스 메서드 구조
#
# * 클래스 내부에 정의되는 메서드의 기본
# * 반드시 첫 인자로 인스턴스 자신(self)을 받음
# * 인스턴스의 속성에 접근하거나 변경가능하다.

# %% [markdown]
# 클래스 메서드
#
# * 클래스 변수를 조작하거나 클래스 레벨의 동작을 수행한다.

# %% [markdown]
# 클래스 메서드 구조
#
# * @classmethod 데코레이터를 사용하여 정의
# * 호출 시, 첫번째 인자로 해당 메서드를 호출하는 class(cls)가 전달됨
# * 클래스를 인자로 받아 클래스 속성을 변경하거나 읽는데 사용

# %% [markdown]
# 스태틱(정적) 메서드
#
# * 클래스, 인스턴스와 상관없이 독립적으로 동작하는 메서드

# %% [markdown]
# 스태틱 메서드 구조
#
# * @staticmethod 데코레이터를 사용하여 정의
# * 호출 시 자동으로 전달받는 인자가 없음(self, cls를 받지않음)
# * 인스턴스나 클래스 속성에 직접 접근하지 않는 '도우미 함수'와 비슷한 역할

# %% [markdown]
# 클래스가 사용해야 할 것
#
# * 클래스 메서드
# * 스태틱 메서드

# %% [markdown]
# 인스턴스가 사용해야 할 것
#
# * 인스턴스 메서드
