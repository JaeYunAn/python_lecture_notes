# %% [markdown]
# # 1강: 텍스트 파운데이션 살펴보기

# %% [markdown]
# # 1. 텍스트 파운데이션 모델 살펴보기

# %% [markdown]
# # 1-1. 텍스트 파운데이션 모델이란?

# %% [markdown]
# 파운데이션 모델의 3가지 구성 요소 in 언어 모델 (Language Model)
# - GPT-1, BERT와 같은 언어 모델에도 3가지 구성 요소가 이미 포함되어 있음
# - GPT-2,
