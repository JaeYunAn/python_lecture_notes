# %% [markdown]
# # 1강: 선형회귀

# %% [markdown]
# # 1. 선형회귀

# %% [markdown]
# # 1-1. 선형회귀(Linear Regression)

# %% [markdown]
# 선형회귀란?
# - 입력 변수와 출력 변수 사이의 관계를 직선 형태로 근사하여, 예측하는 통계적 방법이다.
# - 지도학습의 가장 기초가 되는 접근 중 하나이다.
# - 단순해 보이지만, 선형회귀는 개념적으로도, 실무적으로도 매우 유용하다.

# %% [markdown]
# # 1-2. 광고데이터 예시

# %% [markdown]
# 선형회귀를 통해 대답할 수 있는 질문들
# - 광고비와 매출 사이에 관계가 있는가?
# - 그 관계의 강도는 어느 정도인가?
# - 어떤 매체가 매출에 기여하는가?
# - 미래 매출을 얼마나 정확히 예측할 수 있는가?
# - 매체 간에 상호작용(시너지)가 있는가?

# %% [markdown]
# # 2. 단순선형회귀(Simple Linear Regression)

# %% [markdown]
# # 2-1. 단순선형회귀: 단일 설명변수를 이용한 선형회귀

# %% [markdown]
# 단순선형회귀(simple linear regression)란?
# - 한 개의 설명변수(x)와 하나의 반응변수(Y) 사이의 선형(직선) 관계를 찾는 방법
# - 목표: 데이터를 가장 잘 설명하는 직선을 찾아 예측(y_hat)에 활용

# %% [markdown]
# # 2-2. 최소제곱법(least squares)

# %% [markdown]
# 최소제곱법(least squares)이란?
# - 실제 관측값과 예측값의 차이(잔차, residual)를 제곱해 합한 값(RSS, 잔차제곱합)을 최소화 하는 방법
# - 목표: 데이터를 가장 잘 설명하는 직선을 찾기 위해 B0, B1을 추정

# %% [markdown]
# # 2-3. 단순선형회귀: 광고 데이터

# %% [markdown]
# 사례 설명
# - 목표: TV 광고비(X)와 제품 판매량(Y)의 선형 관계 예측
# - 단순선형회귀를 적용하여, 각 데이터에서 잔차제곱을 가장 적게 만드는 직선(최소제곱법)이 선택됨

# %% [markdown]
# # 3. 다중선형회귀(Multiple Linear Regression)

# %% [markdown]
# # 3-1. 다중선형회귀(Multiple Linear regression)란?

# %% [markdown]
# 단순선형회귀와 다중선형회귀
# - 단순 선형 회귀: 'TV 광고 -> 매출' 한 가지 관계만 고려
# - 다중 선형 회귀: 'TV 광고, Radio 광고비, 가격, 계절, 경쟁사' 등 복수 요인을 함께 고려하여 매출을 설명

# %% [markdown]
# 다중선형회귀의 개념
# - 독립 변수(설명 변수, Feature)가 여러개 존재할 때 사용하는 회귀 분석 기법
# - 단순 선형 회귀는 하나의 변수만 고려하지만, 다중 선형회귀는 여러 독립 변수(X1, X2, ....)를 동시에 고려하여, 종속 변수(Y)와의 관계를 구함

# %% [markdown]
# 각 변수의 의미
# - Y: 종속 변수(예측 대상, 예: 매출)
# - X1, X2, X3, ..., Xp: p개의 독립 변수들(예: 광고비, 가격, 계절 등)
# - B0: 절편
# - B1, B2, B3, ...., Bp: 각 독립 변수에 대한 회귀 계수(모수) -> 변수의 영향력 크기와 방향을 나타냄
# - 앱실론: 관측오차 (모델이 설명하지 못하는 부분, 오류 / 잔차가 아니다.)

# %% [markdown]
# # 3-2. 다중선형회귀의 추정과 예측

# %% [markdown]
# 다중선형회귀: 계수 추정과 예측
# - 여러 변수로 변수 Y를 동시에 예측하는 모형
# - 추정 방법: 실제 값과 예측 값의 차이를 제곱해 합한 값(RSS)를 최소화

# %% [markdown]
# # 4. 선형회귀 주의사항

# %% [markdown]
# # 4-1. 검증 / 테스트셋 데이터를 활용한 성능 평가

# %% [markdown]
# 선형회귀 결과 검증 및 테스트 성능
# - 훈련 데이터에서의 성능
#   - 회귀식을 만들 때 최소제곱 해는 훈련 데이터만 보고 계산됨
#   - 학습에 사용된 훈련 데이터에서는(X와 Y의 평균적인 선형관계가 있다면) 적합(fitting)이 잘 되어 있을 것임.
#   - 그러나 이것은 테스트 성능을 과소평가할 가능성이 높음
# - 테스트 성능 평가 필요
#   - 선형회귀도 변일반화 성능을 확인하려면 훈련에 사용되지 않은 새로운(테스트) 데이터에 적용해 봐야 함
#   - 수가 많거나 고차항을 사용하면 과적합(overfitting)문제가 여전히 발생할 수 있음
#   - 검증 / 교차 검증을 통해서 적절한 적합을 찾을 수 있음

# %% [markdown]
# # 4-2. 다중선형회귀시 회귀계수 해석의 주의점

# %% [markdown]
# 선형회귀를 통해 대답할 수 있는 질문들
# - 이상적 상황: 변수들이 연관(correlation)되지 않고, 독립적일 떄 -> 계수 해석이 명확함
# - 문제 상황: 변수들이 서로 연관되어 있다면 -> 계수 추정이 불안정해지고 해석에 혼동이 생길 수 있음
# - 주의: 관찰 데이터의 상관관계로 인과 관계를 주장해서는 안됨
#   - 예로 들었던, 광고 데이터는 자연스럽게 인과성이 있는 것 처럼 보이지만, 다른 많은 데이터에서 선형 관계를 보인다고 하여 인과 관계가 있는 것이 아님
#     - 예: '아이스크림 소비량'(X) vs '상어에 물리는 사건'(Y)

# %% [markdown]
# # 2강: 로지스틱 회귀

# %% [markdown]
# # 1. 분류

# %% [markdown]
# # 1-1. 분류(Classification)란?

# %% [markdown]
# 분류의 정의
# - 분류: 정해진 범주(카테고리)중 하나로 지정하는 것
# - 범주형 변수: 수치의 크고 작음이 아니라 유한한 범주(성별, 혈액형, 지역 등)로 표현하는 변수
#   - 예: 눈동자 색 {black, brown, blue, green}, 이메일 종류 {spam, normal}

# %% [markdown]
# 분류 함수의 목표
# - 입력(X, 특성 벡터): 눈동자 이미지, 이메일 내용 / 제목
# - 출력(Y E C, 범주): 예, 눈동자 색 C = {black, brown, blue, green}, 이메일 C = {spam, normal}, 순서없는 집합
# - 분류 함수의 목표
#   - 분류 함수 f(X)를 학습하여 입력 X가 속할 범주(카테고리)를 예측
#   - 범주의 직접 예측보다 각 범주에 속할 확률 P(Y = k | X)를 추정하는 것이 더 유용할 때가 많음

# %% [markdown]
# # 1-2. 예시: 신용카드 연체(Default)

# %% [markdown]
# 신용카드 사용량 및 소득에 대한 연체 여부 산점도
# - 신용카드 사용량(Balance) - 소득(Income) 산점도에 연체(Default) 여부를 색상 및 부호로 구분
# - 신용카드 사용량과 소득은 각각 독립변수, 연체 여부가 종속 변수

# %% [markdown]
# 신용카드 사용량 - 소득 산점도 해석
# - 연체자는 신용카드 사용량이 높은 구간에 집중적으로 분포
# - 연체가 없는 사람은 신용카드 사용량이 낮은 쪽에 주로 분포
# - 소득은 연체 여부와 뚜렷한 상관을 보이지 않음

# %% [markdown]
# 그룹별 분포(Boxplot)
# - 신용카드 사용량(Balance), 소득(Income)에 대해 연체(Default)의 그룹별 분포(Boxplot)
# - 신용카드 사용량과 소득은 각각 독립변수, 연체 여부가 종속 변수

# %% [markdown]
# 그룹별 분포 해석
# - 신용카드 사용량(Balance) vs 연체(Default)
#   - 연체자의 신용카드 사용량이 연체하지 않은 사람보다 전반적으로 높음
#   - 중앙값도 높고, 분포가 퍼져있는 정도도 더 큼
# - 소득(Income)  vs 연체(Default)
#   - 연체 여부에 따른 소득 차이는 거의 없음
#   - 중앙값이 약간 다르긴 하지만 분포가 대부분 겹침

# %% [markdown]
# # 1-3. 분류 문제에 선형회귀를 써도 될까?

# %% [markdown]
# 선형회귀는 분류 문제에 사용하기에 부적절함: 이진 분류 문제
# - 선형회귀는 선형함수를 계산하는 문제로 예측 값이 (Y값 기준) 제한된 값을 갖게 못함
# - 따라서 선형 회귀는 예측 확률이 0보다 작거나 1보다 크게 예측될 수 있어 확률로 쓰기 부적절함

# %% [markdown]
# # 1-4. 분류 문제에서 적합한 모델

# %% [markdown]
# 분류 문제에서 선형회귀의 대안 - 로지스틱 회귀(Logistic Regression)
# - 시그모이드(Sigmoid) 함수를 활용해 0 ~ 1 범위 내 확률값 예측 보장
# - 순서가 없는 범주를 확률로 직접 예측하는 적절한 분류 방법

# %% [markdown]
# # 2. 로지스틱 회귀(Logistic Regression)

# %% [markdown]
# # 2-1. 로지스틱(Logistic)회귀의 모형식

# %% [markdown]
# 이진 분류에서의 적절한 함수
# - 함수의 출력 범위가 모든 입력에 대해서 0 ~ 1 사이의 범위를 가지는 함수를 활용하자

# %% [markdown]
# 출력 범위가 0 ~ 1인 시그모이드(Sigmoid) 함수
# - 기울어진 S자 형태의 곡선 함수
# - 모든 실수 z에 대한 y값의 범위는 0 <= y <= 1이다.
#   - z가 무한대라면 y는 1에 수렴한다
#   - z가 -무한대라면 y는 0에 수렴한다

# %% [markdown]
# # 2-3. MLE 활용 모수 추정

# %% [markdown]
# 우도(Likelihood)
# - 확률을 추정하는 모델을 결정했으니, 모수(B0, B1)를 추정하는 방법에 대해 알아보자
# - 선형회귀에서 '현재 함수가 데이터와 오차가 작은지'를 평가하기 위해 MSE를 지표로 삼았듯, 확률을 계산하는 함수를 평가하기 위해선 우도(Likelihood)를 지표로 삼는다.
# - 우도란 '현재 확률 함수가 데이터를 얼마나 잘 설명하는지'를 나타낸 지표이다.
#   - 그러므로, 모델의 학습은 우도 값을 높여 최대화가 되도록 하는 것이 목표이며 이를 Maximum Likelihood Estimation (MLE)이라 한다.

# %% [markdown]
# 로지스틱 회귀의 우도 최대화
# - 로지스틱 회귀와 같은 이진 분류 문제에서 우도를 최대화한다.
# - 하지만, 위와 같은 곱으로 이뤄진 함수의 경우 B에 대해 미분이 어렵기 때문에 양 변에 log를 취해 곱셈을 더하기로 변환시킨 뒤 log-likelihood를 만들어 최대화한다.

# %% [markdown]
# # 3강: 신경망 모델

# %% [markdown]
# # 1. 모수적 함수로서의 선형 모델

# %% [markdown]
# # 1-1. 단순(1D) 선형 모델: 모수적 함수

# %% [markdown]
# 순차적으로 모수(parameter)를 조정하면서 찾아 내는 선형회귀

# %% [markdown]
# # 2. Shallow 네트워크

# %% [markdown]
# # 2-1. Shallow 네트워크

# %% [markdown]
# 정의
# - 입력층(Input) - 은닉층(Hidden Layer) 1개 - 출력층(Output)으로 구성된 1개의 은닉층만 가진 신경망 구조

# %% [markdown]
# 장점
# - 복잡한 비선형 패턴까지 학습 가능
#   - 단순 선형 모델 대비 표현력 향상
# - 구조가 간단해 학습 속도가 빠르고 구현이 쉬움
# - 데이터가 충분하지 않아도 과적합 위험이 비교적 낮음

# %% [markdown]
# 사용 예시
# - 간단한 분류(Classification) 및 회귀(Regression) 문제
# - XOR 같은 비선형 결정 boundary가 필요한 문제

# %% [markdown]
# # 2-1. Shallow 네트워크 vs 1D 선형회귀

# %% [markdown]
# 활성화 함수 = 렐루

# %% [markdown]
# # 3. Shallow 네트워크의 표현력

# %% [markdown]
# # 3-1. 더 많은 Hidden Unit 가능

# %% [markdown]
# # 3-2. Hidden Unit을 많이 두면

# %% [markdown]
# 충분히 많은 Hidden Unit이 있다면, 임의의 1차원 함수를 원하는 정확도로 근사할 수 있다.
# - Hidden Unit이 3개면 Output 그래프의 꺾인 꼭짓점이 3개임

# %% [markdown]
# # 3-3. 보편적 근사 정리(Unisersal approximation theorem)

# %% [markdown]
# Hidden unit을 충분히 많이 갖는다면, 얕은 신경망은 임의의 연속함수를 임의의 정밀도로 근사할 수 있다.

# %% [markdown]
# # 4. 다중 출력 / 입력

# %% [markdown]
# # 4-1. 2개 출력의 네트워크

# %% [markdown]
# 1 input, 4 hidden units, 2outputs

# %% [markdown]
# # 4-2. 2개 입력의 네트워크

# %% [markdown]
# 2 input, 3 hidden units, 2outputs

# %% [markdown]
# # 4-3. 2개 입력의 네트워크: 단계별 계산

# %% [markdown]
# - 1. 선형 변환
# - 2. 활성화 함수 적용
# - 3. Hidden unit에 상수배 적용
# - 4. 3개 함수의 합

# %% [markdown]
# # 5. Deep 네트워크

# %% [markdown]
# # 5-1. 2개의 네트워크를 하나로 합성

# %% [markdown]
# # 5-4. Shallow 네트워크와 Deep 네트워크 비교

# %% [markdown]
# 같은 hidden unit의 개수를 이용할 때 Shallow 네트워크보다 Deep 네트워크가 더 표현력이 높다

# %% [markdown]
# # Deep 네트워크 수식 표현

# %% [markdown]
# # 6-1. 2개의 네트워크를 하나로 합성: 복잡한 수식

# %% [markdown]
# # 4강: 신경망 적합

# %% [markdown]
# # 1. 선형회귀 예시

# %% [markdown]
# # 1-1. 손실함수

# %% [markdown]
# 손실함수
# - 학습 데이터 셋: input / output I개 쌍
# - 손실함수(Loss funtion): 모델이 얼마나 잘못 예측하는지를 측정하는 함수

# %% [markdown]
# # 1-2. 학습

# %% [markdown]
# 손실함수
# - 학습: 손실함수를 최소화하는 파라미터를 찾음

# %% [markdown]
# # 1-3. 1D 선형회귀 예

# %% [markdown]
# 1D 선형회귀 예
# - 선형회귀 모델에서 손실함수는 예측값과 실제값의 차이를 제곱하여 합산한 값(최소제곱 손실함수, MSE)
# - 학습의 목적은 이 손실함수를 최소화하는 직선을 찾는 것
# - 손실함수 정의(최소 제곱 손실함수)

# %% [markdown]
# # 1-4. 1D 선형회귀 학습

# %% [markdown]
# 선형회귀 학습
# - 등고선: 손실 함수 값의 크기
# - 데이터와 선형함수 직선: 데이터와 선의 오차가 크다면 손실값이 큼

# %% [markdown]
# 경사하강법(gradient descent)
# - 손실 함수의 값이 줄어드는 방향으로 파라미터를 이동하는 과정

# %% [markdown]
# # 2. 수학 리뷰

# %% [markdown]
# # 2-1. 미분을 이용한 최적화

# %% [markdown]
# 미분을 통한 기울기 이해
# - 이차 함수로, 그래프는 위로 열린 포물선
# - 미분 결과(2x - 4)는 기울기를 의미
#   - 기울기가 0이 되는 지점이 극값(최소값)

# %% [markdown]
# # 3. 경사하강

# %% [markdown]
# # 3-1. 경사 하강법

# %% [markdown]
# 경사 하강(Gredient descent) 알고리즘
# - 경사 하강법은 손실함수를 최소화 하기 위해 파라미터를 반복적으로 갱신하는 알고리즘
# - 기울기 계산: 손실함수를 파라미터에 대해 편미분(각 원소에 대한 미분) 진행
#   - 벡터 형태의 기울기
# - 파라미터 업데이트
#   - 기울기(미분값)의 반대 방향으로 이동해야 손실 함수가 줄어듦

# %% [markdown]
# 손실 함수의 기울기 계산
# - 경사 하강법의 첫 단계: 편미분(전체 손실에 대한 기울기) 구하기

# %% [markdown]
# # 3-4. 함수에 따른 최적화 난이도

# %% [markdown]
# Convex vs Non-convex 최적화 문제
# - Convex: 곡선이 항상 U자처럼 아래로 볼록. 그래프 위 임의 두 점을 잇는 직선이 그래프 위(또는 같은 위치)로 있음.
# - Non-convex: 봉우리, 골짜기, 오목한 구간이 섞인 모양. 두 점을 이은 직선이 그래프 아래로 내려가는 구간이 생김
# - 손실 함수의 모양에 따라 최적화의 난이도가 달라짐
#   - Convex 문제: 전역(global) 최소값이 유일함 -> 최적화가 쉬움
#   - Non-Convex 문제: 여러 개의 지역(local) 최소값 또는 새들(saddle)점이 있음 -> 최적화가 어려움

# %% [markdown]
# # 4. 확률적 경사 하강법

# %% [markdown]
#   # 4-1. 경사 하강법 VS 확률적 경사 하강법

# %% [markdown]
# 경사 하강법 단점
# - Non-convex문제에서 지역 최소점에 빠지기 쉬움
# - 매 스텝마다 전체 데이터에 대한 미분값을 구하여 업데이트함.
#   - 스텝별 계산양이 많음

# %% [markdown]
# 대안: 전체 데이터를 한번에 쓰는 대신, 무작위로 선택한 데이터 샘플 사용
# - 확률적 경사 하강법(Stochastic Gradient Decsent, SGD)

# %% [markdown]
# # 4-2. 확률적 경사 하강법의 개념

# %% [markdown]
# 업데이트 방식의 차이점
# - 경사 하강법(Gradient Descent)
#   - 전체 데이터셋을 사용하여 기울기를 계산하고(미분)하고 파라미터 업데이트
# - 확률적 경사 하강법(SGD Mini-batch 버전)
#   - 무작위 확률로 샘플된 일부 데이터(batch)만 사용하여 기울기 계산

# %% [markdown]
# # 4-4. 확률적 경사 하강법의 특성

# %% [markdown]
# 확률적 경사 하강법(SGD)의 특성
# - 무작위 샘플 데이터를 활용한 미분으로 경로의 무작위성이 있음
# - Local 최소점에서 빠질 위험이 상대적으로 적음
# - 국소 최솟값
#   - 전체 데이터가 아닌 일부 배치로 기울기를 계산하기 때문에 노이즈가 섞여있음
#   - 노이즈가 오히려 local minima, saddle point에서 빠져나오는 도움이 됨
# - 노이즈가 있지만 여전히 타당한 업데이트
#   - 미니배치의 기울기는 정확한 전체 기울기가 아니지만, 평균적으로 올바른 방향 가리킴
#   - 학습이 점진적 최적점 방향으로 수렴
# - 계산 비용 절감
#   - 전체 데이터셋에서 작은 배치만 사용하므로 반복(스텝)당 연산량이 적음
#   - 큰 데이터셋에서 효율적으로 학습 가능
# - 수렴 특성
#   - full batch처럼 매끄럽게 수렴하지 않고, 무작위성 때문에 더 많이 진동(jitter, 지그재그)하면서 움직임
#   - 전역 최솟값 근처의 좋은 해에 도달할 수 있음. Convex 문제에서는 full-batch 경사하강보다 수렴이 늦을 수 있음

# %% [markdown]
# # 5. 역전파(Backpropagation)

# %% [markdown]
# # 5-1. 네트워크 파라미터의 미분

# %% [markdown]
# 네트워크 파라미터의 미분값을 어떻게 구할까?
#  - Layer별로 파라미터들이 존재함. 서로 영향을 미침

# %% [markdown]
# # 5-2. 합성함수의 미분: 연쇄법칙

# %% [markdown]
# 연쇄법칙
# - 파라미터는 오메가를 갖는 합성 함수를 미분하면?

# %% [markdown]
# # 5-3. 역전파

# %% [markdown]
# 역전파란?
# - 출력 오차를 기준으로 그래프를 거꾸로 따라가며 연쇄법칙으로 각 노드(파라미터 포함)의 미분값을 계산하는 절차
# - 1. 각 단계별 계산을 분해
# - 2. 각 layer별 값을 계산
# - 3. 각 layer별 값에 대한 출력 손실의 미분을 구함
# - 4. 파라미터에 대한 미분을 구함

# %% [markdown]
# 손실로부터 각 layer별 파라미터의 미분을 거꾸로 구할 수 있다.
