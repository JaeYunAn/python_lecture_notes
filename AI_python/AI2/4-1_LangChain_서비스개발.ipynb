# %% [markdown]
# # 1강: Post-training

# %% [markdown]
# # 1. Pre-training vs Post-training

# %% [markdown]
# 거대 언어 모델 학습 패러다임
# - 최근 거대 언어 모델을 학습하기 위해서는 크게 두 가지 단계로 나눠진다.
#   - Pre-training(사전 학습): 방대한 텍스트 데이터를 통해 언어와 지식을 배우는 단계
#   - Post-training(사후 학습): 사람이 원하는 방식으로 대화하고, 안전하고, 유용하게 만드는 단계

# %% [markdown]
# Pre-training(사전 학습)
# - 방대한 텍스트 데이터를 이용한 Self-supervised learning을 통해 언어 패턴, 지식 등을 배운다
