# %% [markdown]
# # 원-핫 인코딩
# - 단어를 0 / 1 벡터로 단순 구분(의미 정보 없음)
# - 문제점
#   - 차원의 저주, 의미적 유사성 부족, 직교 문제

# %% [markdown]
# # 워드 임베딩
# - 단어를 밀집 실수 벡터로 표현
#   - 의미적 관게 반영
# - Word2Vec
#   - 단어와 주변 단어의 관계 예측
# - Skip-gram
#   - 중심단어를 기준으로 주변 단어 예측
# - CBOW
#   - 주변 단어를 기준으로 중심 단어를 예측

# %% [markdown]
# # 순차적 데이터
# - 순서가 중요, 장기 의존성 존재, 가변 길이 처리 필요
# - 대응 모델
#   - RNN
#   - LSTM
#   - Transformer

# %% [markdown]
# # RNN
# - 이전 hidden state를 활용해 순차 데이터 처리
# - 장점
#   - 가변 길이 입력, 순서 반영 가능
# - 한계
#   - 기울기 소실 문제 -> 장기 의존성 학습 어려움

# %% [markdown]
# # LSTM
# - RNN의 기울기 소실 문제 해결
# - Cell state + hidden state 구조
# - 3가지 게이트
#   - Forget / Input / Output -> 정보 흐름 제어

# %% [markdown]
# # 언어모델이란?
# - 주어진 문맥에서 다음 단어의 확률을 예측하여 추천하는 모델
# - N-gram 언어모델은 직전 N개의 단어만 고려하여 다음 단어를 예측

# %% [markdown]
# # Seq2Seq
# - 인코더와 디코더를 활용하여 입출력 길이가 다른 작업(번역 등)에 활용한다.
# - 역전파를 통해 인코더 - 디코더 통합 학습한다. (End-to-End)

# %% [markdown]
# # Attention
# - Seq2Seq의 Bottleneck Problem을 해결하며 긴 시퀀스에서 정보 손실을 방지한다.
# - 디코더가 필요한 부분에만 집중할 수 있게 하여 성능을 향상시킨다.

# %% [markdown]
# # Self-Attention의 동작 원리
# - 입력 문장 -> 각 단어를 Query, Key, Value 벡터로 변환 -> 단어 간 연관성을 수치화
# - Query와 Key 벡터 내적 -> Attention Score -> Value에 가중합하여 출력 벡터 생성

# %% [markdown]
# # Self-Attention의 한계와 극복
# - 단어간 유사도만 연결하는 한계 -> Positional Encoding (위치 벡터 정의) -> 순서 정보 보완
# - 선형 결합만 가능한 한계 -> FNN (Fully Connected + Relu 등) -> 비선형적 표현으로 확장 (복잡한 패턴 학습 가능)
# - 미래 단어 참조로 언어 샏성에 한계 -> Masked Self-Attention (미래 단어 -무한) -> 순차적 단어 생성 가능

# %% [markdown]
# # Transformer의 전체 구조 (인코더 - 디코더 블록)
# - 인코더 블록
#   - 입력 문장을 Self-Attention + Positional Encoding + FNN으로 처리해 문맥 정보가 담긴 의미 분석
# - 디코더 블록
#   - 이전 단어를 Masked Self-Attention으로 처리, 인코더 출력을 참조해 다음 단어를 순차적으로 생성

# %% [markdown]
# # 사전학습(Pretraining) 패러다임
# - 사전학습
#   - 네트워크 초기화 후 단어 의미 및 언어 패턴 학습
# - 패러다임
#   - 사전학습 (언어 패턴 학습) -> 파인튜닝 (태스크 최적화)

# %% [markdown]
# # 3대 모델 유형 비교
# - BERT (Encoder)
#   - 양뱡향
#   - Masked LLM (MLM) 기반 학습
# - T5(E - D)
#   - Text-to-Text
#   - Span Corruption 방식 학습
# - GPT(Decoder)
#   - 단방향
#   - 강력한 텍스트 생성 능력

# %% [markdown]
# # In-Context Learning (ICL) 및 Prompting
# - ICL (GPT - 3 등장 배경)
#   - 모델을 파인튜닝 하지 않고, 자연어 설명 및 예시(Prompt)를 입력으로 제공하여 예측 수행
# - Zero-shot, One-shot, Few-shot 방식이 포함됨
# - Chain-of-Thought (CoT)
#   - ICL 능력을 끌어올리는 기법
#   - 논리적인 사고 단계를 유도하여 최종 답을 도출
