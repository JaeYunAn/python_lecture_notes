# %% [markdown]
# # 1강: AI와 ML은 무엇인가?

# %% [markdown]
# # AI
# - 주어진 환경 / 데이터를 인지, 학습, 추론을 통해 목표 달성을 하도록 예측, 행동 선택, 계획하는 시스템

# %% [markdown]
# # ML
# - AI 범주 내에서 데이터로부터 학습하여 목적을 달성하는 접근 방법론
# - 예
#   - 생성형 AI, 언어 모델, 이미지 분류 모델, 추천 시스템

# %% [markdown]
# # DL
# - ML 범주 내에서 신경말 함수를 사용한 학습 방법론

# %% [markdown]
# # AI - ML(ML이 아닌 AI 시스템)의 예
# - 규칙 기반 시스템
# - 휴리스틱 기반(최적화) 알고리즘

# %% [markdown]
# # 2. 데이터, 모델, 학습

# %% [markdown]
# 머신러닝의 순환: 반복적 개선 루프

# %% [markdown]
# # 2-1. 데이터 구성 요소

# %% [markdown]
# 데이터가 중요한가?
#   - 머신러닝은 규칙을 직접 코딩하지 않고, 데이터에서 규칙을 학습
#   - 데이터(Feature, Label)의 분포와 관계가 머신러닝의 학습 결과를 결정

# %% [markdown]
# Feature (피처, 특성)
#   - 모델이 예측에 사용하는 입력 정보
#   - 예측, 판단의 근거 / 단서

# %% [markdown]
# Label (라벨, 목표값)
#   - 모델이 예측하려는 정답
#   - 학습의 목표값

# %% [markdown]
# # 3. 단일 피쳐 기반 학습

# %% [markdown]
# # 3-1. 1D 피쳐 기반 학습

# %% [markdown]
# 1D 피쳐 기반 학습(단일 피쳐 학습) 이란?
# - 1D = 1차원
# - Feature가 하나일 때 머신러닝이 학습하는 가장 단순한 형태

# %% [markdown]
# Feature와 Label의 관계를 잘 나타내는 함수 f는 없을까?
# - 데이터를 설명하는 여러 함수 후보가 존재
# - 어떤 함수가 잘 맞는지 학습해야함

# %% [markdown]
# # 3-2. 모델과 가설 공간

# %% [markdown]
# 학습(Learning)
# - '입력(Feature) -> 출력(Label)' 관계를 찾는 과정
# - 평균 관계를 하나의 함수로 표현함
# - 하지만 관계를 표현할 수 있는 함수는 무수히 많음

# %% [markdown]
# 가설 공간(Hypothesis Space)
# - 관계를 표현할 수 있는 모든 후보 함수들의 모음
# - 피쳐 공간과 라벨 공간위에서 정의된 함수들의 집합 F

# %% [markdown]
# 모델(Model)
# - 가설 공간 F에 속한 특정 함수 f

# %% [markdown]
# # 3-3. 학습이란

# %% [markdown]
# 학습
# - 주어진 데이터에서 정답을 가장 잘 맞출 수 있도록 모델의 규칙을 조금씩 조정해가는 과정
# - 데이터 D -> 가설공간 F -> 선택된 모델 f

# %% [markdown]
# 학습에 필요한 3가지
# - 1. 데이터(Data)
#   - 학습할 예시들(학력 - 수입 쌍 30개)
#   - 입력(특성)과 정답(라벨) 쌍으로 된 정답 모음
# - 2. 가설 공간(Hypothesis Space)
#   - 선택할 수 있는 모든 후보 함수들의 집합
#   - '이 중에서 가장 좋은 함수를 찾아야만 한다.'
# - 3. 선택 기준(손실 함수)
#   - 어떤 함수가 더 좋은지 판단하는 척도
#   - 예측값과 실제값 차이를 측정

# %% [markdown]
# 학습 과정
# - 1. 가설 공간에서 하나의 함수를 선택
# - 2. 그 함수로 데이터의 모든 예시를 예측
# - 3. 손실함수로 틀린 정도 계산
# - 4. 더 적게 틀리도록 함수의 파라미터 조정
# - 5. 반복하여 최적의 모델 완성

# %% [markdown]
# 데이터 D -> 가설 공간 F -> 선택된 모델 f의 관점으로 생각해보기
# - 데이터가 제시한 문제를, 가설 공간이 제공한 선택지 중에서, 가장 잘 푸는 함수를 찾는 것이 학습

# %% [markdown]
# # 4. 복수피쳐 기반 학습

# %% [markdown]
# # 4-1. 2D 피쳐 기반 학습

# %% [markdown]
# Income = 미지의 참 함수 + 측정 오차(예측값과 실제값 사이의 차이)

# %% [markdown]
# # 4-2. 일반적 용어 정리 및 모델 가정

# %% [markdown]
# Income = f*(Years of Education, Seniority, ...) + 측정 오차 -> Y = f*(X) + 측정 오차
# - Income: 우리가 예측하려는 라벨(반응 / 목표) 변수 -> Y로 표기
# - Years of Education: 첫번째 피쳐(입력 / 예측) 변수 -> X1로 표기
# - Seniority: 두번째 피쳐(입력 / 예측) 변수 -> X2로 표기
# - 다른 i번쨰 피쳐가 있다면 역시 Xi로 표기

# %% [markdown]
# # 4-3. 왜 f()를 학습하는가?

# %% [markdown]
# 예측
# - 잘 학습된 f가 있으면, 새로운 입력 X = x에서 반응 / 목표 Y를 예측할 수 있음

# %% [markdown]
# 중요 특성 파악
# - 피쳐들 X = (X1, X2, ...., Xp)중 어떤 특성이 Y를 설명하는데 중요한지, 어떤게 덜 중요한지 알수 있음

# %% [markdown]
# 해석 가능성
# - f의 복잡도에 따라 각 구성요소 Xi가 Y에 어떻게 영향을 미치는지(증가 / 감소 방향, 민감도 등)을 이해할 수 있음

# %% [markdown]
# # 2강: 지도학습은 무엇인가?

# %% [markdown]
# # 1. 지도학습의 개념

# %% [markdown]
# # 1-1. 지도학습이란?

# %% [markdown]
# 지도학습이란?
# - 정답 라벨이 있는 훈련 데이터를 사용하여 예측 모델을 학습하는 방법
# - 목표: 훈련 데이터로 학습한 모델이 새로운 데이터에서도 정확한 예측을 수행
#   - 데이터: 입력(feature, x)과 정답(label, y)가 항상 한 쌍으로 존재
#   - 데이터들은 여러개 축적되어 있음

# %% [markdown]
# # 1-2. 지도학습의 종류(회귀 VS 분류)

# %% [markdown]
# 회귀(Regression)
# - 예측하고 싶은 결과값이 숫자일 때 사용
# - 예시: 가격, 점수, 온도

# %% [markdown]
# 분류(Classification)
# - 예측하고 싶은 결과값이 범주일 때 사용
# - 예시: 스팸 / 정상, 질병 유 / 무

# %% [markdown]
# # 1-3. 손실 함수(Loss Function)

# %% [markdown]
# 손실 함수란?
# - 모델의 예측이 정답에서 얼마나 벗어낫는지를 하나의 숫자로 나타내는 함수
# - 학습이란, 이 숫자가 작아지는 방향으로 모델을 조금씩 고쳐나가는 과정

# %% [markdown]
# 문제 유형에 따라 쓰는 손실이 다르다
# - 회귀: 평균제곱오차(MSE)
#   - 정답과 예측의 차이를 제곱해서 평균낸 값(많이 틀릴수록 제곱 때문에 손실이 크게 느껴짐)
# - 분류: 교차 엔트로피(Cross Entropy)
#   - 정답 범주에 얼마나 높은 확률을 주었는지 측정(정답에 가까울 수록 0에 가까워짐)

# %% [markdown]
# # 1-4. 지도학습 용어

# %% [markdown]
# 특성(Feature, x)
# - 예측에 사용되는 설명 변수
# - 예측 함수 f의 input으로 들어가는 변수

# %% [markdown]
# 라벨(Label, y)
# - 맞춰야 하는 정답(실제 값)

# %% [markdown]
# 예측값(y_hat)
# - 학습 과정에서 모델이 내놓은 결과(숫자 또는 범주)
# - y의 추정치

# %% [markdown]
# 오류(Error): 손실함수로 계산
# - y_hat과 y의 차이: y_hat - y
# - 이 값을 줄이는 것이 지도학습의 목표이다.

# %% [markdown]
# # 2. 회귀(Regression)

# %% [markdown]
# # 2-1. 회귀(Regression) 문제

# %% [markdown]
# 회귀(Regression)
# - 정의: 입력(feature)으로부터 숫자(output)를 얼마나 정확히 예측할까?
# - 특징: 라벨 및 예측 모델의 출력은 연속적인 수치

# %% [markdown]
# # 2-2. 회귀 오류: 평균제곱오차 (MSE)

# %% [markdown]
# 예측이 얼마나 정확한지 어떻게 알 수 있을까?
# - 모델의 예측 정확도를 숫자로 측정하는 지표 필요

# %% [markdown]
# 평균제곱오차(MSE)
# - 각 데이터에서 정답(y)과 예측(y_hat)의 평균 제곱 차이값
# - 틀린 정도를 제곱해서 더 큰 오류에 패널티 부여
#   - 전체 평균 오류 수준을 한 눈에 볼 수 있음

# %% [markdown]
# 참고: MSE의 단위가 제곱이라 해석이 어렵다면?
# - 원래 데이터와 같은 단위라서 해석이 쉬운 RMSE(MSE의 제곱근)도 사용

# %% [markdown]
# # 2-3. 회귀 설명력: R2(결정계수)

# %% [markdown]
# 결정계수(R2)
# - Label(y)의 분산 중에서 Feature로 설명되는 비율
# - 평균만 쓰는 단순한 예측보다 모델이 실제값을 얼마나 더 잘 맞추는지를 0 ~ 1 사이 값으로 나타냄
# - 1에 가까울 수록 설명력이 높고, 낮을수록 설명력이 낮음
# - 모델링을 정말 못하면 R2값이 마이너스(-)가 뜰 수도 있음

# %% [markdown]
# # 2-4. MSE vs R2

# %% [markdown]
# # 3. 분류(Classification)

# %% [markdown]
# # 3-1. 분류(Classification) 문제
# 분류(Classification)
# - 정의: 입력 특성(Feature)으로부터 출력이 범주값(카테고리)으로 나타나는 예측 문제
# - 특징: 범주 라벨(이진 / 다중)
#   - 분류 모델에서 라벨은 미리 정해진 범주(카테고리) 중 하나의 값을 가짐

# %% [markdown]
# # 3-2. 분류 정확도(Accuracy)

# %% [markdown]
# 분류 모델의 예측 정확도는 어떻게 평가할까?
# - 분류모델은 Label이 범주로 돼 있기 때문에 MSE나 R2를 사용하기 어려움

# %% [markdown]
# 정확도
# - 전체 예측 중에서 올바르게 맞춘 예측의 비율

# %% [markdown]
# 정확도가 99%라면 항상 좋은 모델일까?
# - 불균형 데이터(양성 1%, 음성 99%)에서는 전부 음성이라 해도 정확도가 99%로 보일 수 있음
# - 고장나서 전부 음성이라고 하는 모델도 정확도가 99%로 나온다는 말임
# - 정확도는 단순히 '전체 비율 중 맞춘 비율'만 계산하니까 정확도만 보지 말고 다른 지표도 봐야함
#   - 예: 혼동행렬

# %% [markdown]
# # 3-3. 혼동행렬(Confusion Matrix)

# %% [markdown]
# 혼동행렬
# - 예측과 실제 값 사이의 관계를 행렬 형태로 표현
# - TP: 실제 양성, 예측도 양성
# - TN: 실제 음성, 예측도 음성
# - FP: 실제 음성인데 양성으로 예측함(오탐)
# - FN: 실제 양성인데 음성으로 예측함(누락)

# %% [markdown]
# 정밀도(Precision)
# - 양성이라 판정한 것 중 진짜 양성의 비율 = TP / (TP + FP)

# %% [markdown]
# 재현율(Sensitivity or Recall)
# - 진짜 양성 가운데 잡아낸 예측 양성 비율 = TP / (TP + FN)

# %% [markdown]
# F1-score
# - 정밀도와 재현율의 조화평균
# - F1 = 2 * {(정밀도 * 재현율) / (정밀도 + 재현율)}

# %% [markdown]
# # 3-4. 분류 손실: 교차 엔트로피(Corss Entropy)

# %% [markdown]
# 정확도만 보고 학습할 수 있을까?
# - 정확도, 혼동행렬은 학습이 끝난 결과를 평가하는 지표이다.
# - 맞음 / 틀림만 세므로, 예측 확률이 0.51에서 0.95로 좋아져도 값은 그대로이다.
# - 학습 중에는 정답을 얼마나 확신했는지 반영하는 손실이 필요하다.

# %% [markdown]
# 교차 엔트로피(Cross Entropy)
# - 정답에 준 확률이 높을수록 손실이 작아짐
# - 확률이 낮으면 손실이 급격히 커짐

# %% [markdown]
# # 4. 학습의 목적

# %% [markdown]
# # 4-1. 학습의 목적

# %% [markdown]
# 학습의 목적: 새로운 데이터에서 예측하기
# - 목적: 훈련 데이터로 학습한 모델이 새로운 데이터에서도 정확한 예측을 수행하도록 하는 것

# %% [markdown]
# 훈련이 잘 됐는지 어떻게 확인할까? (모델 성능을 어떻게 평가할까?)
# - 학습 모델의 성능 평가는 모델이 처음 보는(학습에 사용되지 않은) 데이터로 평가
#   - 이 모델이 훈련 상황 외의 새로운 상황에서도 잘 동작할까? (일반화)를 검증
# - 훈련 데이터에서 성능이 아무리 좋아도, 새로운 데이터에서 성능이 떨어지면 실전 사용 불가
#   - 일반화(generalization) 오류의 최소화 지향
#     - 새로운 데이터에서 틀리는 걸 최대한 줄여야 한다.

# %% [markdown]
# # 4-2. 오버피팅(overfitting)이란?

# %% [markdown]
# 오버피팅(overfitting)
# - 훈련 데이터의 우연한 패턴 / 잡음까지 다 외워버려서 훈련에서는 잘 맞지만 테스트에서는 성능이 나빠지는 현상
# - 현상: 훈련 오류 급격히 낮음, 테스트 오류 높음 / 요동
# - 훈련 집단에 과하게 맞춰버리면 샘플 몇 개만 바뀌어도 예측이 크게 흔들림
# - 일반화 실패: 보지 못한 데이터(테스트) 오류가 커짐, 모(population)집단 성능과 격차가 벌어짐

# %% [markdown]
# # 4-3. 오버피팅에 대한 오해

# %% [markdown]
# 오버피팅 /= 분포 변화(distribution shift)로 인한 에러 증가
# - 분포 변화로 인한 오류: 훈련 데이터 분포와 테스트 분포가 다름으로(환경, 계절, 센서 변경 등) 성능이 떨아지는 현상
# - 분포 변화로 인한 에러 증가는 모델이 과적합하지 않아도 발생 가능

# %% [markdown]
# # 4-4. 오버피팅 VS 언더피팅

# %% [markdown]
# 오버피팅 VS 언더피팅 (균형잡기)
# - 오버피팅: 모델이 너무 복잡 -> 잡음까지 학습(테스트 성능 나쁨)
# - 언더피팅: 모델이 너무 단순하거나 학습이 완료되지 않음 -> 중요한 패턴을 놓침(오류 큼)

# %% [markdown]
# 해결 실마리
# - 더 많은 데이터, 테스트 데이터를 활용한 모델 선정. 교차 검증

# %% [markdown]
# # 3강: 교차검증

# %% [markdown]
# # 1. 테스트 성능 평가

# %% [markdown]
# 훈련 오류 vs 테스트 오류
# - 훈련 오류: 모델을 학습시킨 같은 데이터에 다시 적용해 계산한 오류
# - 테스트 오류: 학습에 쓰지 않은 새 관측치에 대해 모델을 적용했을 때의 평균 예측 오류
#   - 훈련 오류 = 문제집 점수, 테스트 오류 = 시험 점수
#   - 문제집만 잘 푼다고 시험을 잘 본다고 확신을 할 수 없음
# - 보통 훈련 오류는 테스트 오류와 다르며, 특히 훈련 오류는 테스트 오류를 (심하게) 과소평가 하는 경우가 많음
#   - 예: 암기 vs 응용 시험

# %% [markdown]
# 테스트 예측 오류 계산
# - 이상적 케이스: 충분히 큰 별도 테스트 데이터 셋 -> 현실에선 구하기 어려움
# - 현실에서는 테스트만을 위한 데이터를 갖기에 데이터 자체가 부족할 수 있음

# %% [markdown]
# 대안: 재표본화(resampling)를 통한 테스트 오류 추정
# - 데이터를 나눠 여러번 '훈련 -> 평가'를 반복해 테스트 오류를 가늠
#   - 시험용 문제가 따로 없다면 기존 문제집의 문제들을 활용해 모의고사를 보자
# - 방법: 검증셋(hold-out), K겹 교차검증(K-fold Cross-Validation)
# - 장점: 별도의 테스트 데이터 없이 데이터를 더 효율적으로 사용하여 일반화 오차 추정

# %% [markdown]
# # 2. 검증셋(Validation Set) 접근

# %% [markdown]
# # 2-1. 검증셋(Validation Set) 방법
# 검증셋(홀드아웃) 방법
# - 가용 샘플들을 무작위로 훈련셋과 검증셋(hold-out)으로 분할
#   - 문제집의 문제들을 모의고사용과 학습용으로 나누고 모의고사는 딱 1번만 보기
# - 훈련셋으로 모델 적합, 검증셋으로 예측 후 검증 오류를 계산
# - 검증 오류는 보통 정량 반응은 MSE, 범주 반응은 오분류율(또는 F1-score)을 측정한다.

# %% [markdown]
# # 2-2. 검증셋 절차

# %% [markdown]
# 검증 절차
# - 데이터 순서 무작위 셔플링 후 두 부분으로 분할(반반이 아닌 70% 30% 이런식으로)
# - 학습은 훈련셋에서, 성능평가는 검증셋에서 수행

# %% [markdown]
# # 2-3. 검증셋 방법 예시

# %% [markdown]
# # 3. K-겹 교차검증

# %% [markdown]
# # 3-1. K-겹 교차검증

# %% [markdown]
# K-겹 교차검증(K-fold Cross-Validation)
# - 테스트 오류 추정의 표준적 접근
#   - 문제집을 5등분 해서 서로 다른 모의고사를 5번 보는 것
# - 추정치는 모델 선택과 최종 모델의 테스트 오류 규모 파악에 활용
# - 데이터 전체를 크기 동일한 K개 폴드로 무작위 분할
#   - 폴드 K를 검증, 나머지 K - 1개를 훈련에 사용
# - K=1, ..., K에 대해 반복 후, 평균 오류로 테스트 오류를 추정

# %% [markdown]
# K-겹 교차검증 단계
# - 데이터를 먼저 셔플링 한 뒤, 총 n개의 데이터를 겹치지 않는 K개 그룹으로 분할
# - 각 그룹이 번갈아 검증셋, 나머지는 훈련셋
# - K개의 MSE를 평균해 테스트 오류를 추정

# %% [markdown]
# # 3-2. K-겹 교차검증 오류 계산

# %% [markdown]
# K-겹 교차검증 오류 계산
# - 폴드 집합 C1, C...., Ck, 각 폴드 크기 nk
# - 각각의 K의 MSE를 평균내자는 말임
