# %% [markdown]
# 모듈
# 한 파일로 묶인 변수와 함수의 모음
# 특정한 기능을 하는 코드가 작성된 파이썬 파일(.py)

# %% [markdown]
# 모듈 예시
# * math 내장 모듈
# * 파이썬이 미리 작성해 둔 수학 관련 변수와 함수가 작성된 모듈

# %%
import math

print(math.pi)
print(math.sqrt(4))    # sqrt는 제곱근이다.
# Out:
# 3.141592653589793
# 2.0

# %% [markdown]
# import문 사용
# * 같은 이름의 함수가 여러 모듈에 있을 때 충돌을 방지 할 수 있음
# * '.(dot)' 연산자 -> 점의 왼쪽 객체에서 점의 오른쪽 이름을 찾아라
# *** print(math.sqrt(4)) -> math 에서 sqrt()를 찾아라
# 단점: 코드가 길어질 수 있다.

# %% [markdown]
# from절 사용
# * 필요한 것만 집어서 가져오는 방식

# %%
from math import pi, sqrt

print(pi)
print(sqrt(4))
# Out:
# 3.141592653589793
# 2.0

# %% [markdown]
# import 모듈
# 모듈 이름이 짧고, 어디서 온 함수인지 드러내고 싶을 때 사용한다.(math.pi)

# %% [markdown]
# from 모듈 import 대상
# 특정 함수 / 변수를 자주 반복 호출 할 때, 모듈 경로가 깊을 때

# %% [markdown]
# import 시 이름 충돌 다루기
# 같은 이름을 두번 가져오면 나중 것이 이긴다.

# %%
from math import sqrt    # math.sqrt
from my_math import sqrt    # my_math.sqrt 가 덮어씀

result = sqrt(9)    # my_math.sqrt 가 호출됨

# %% [markdown]
# as 키워드
# as 키워드를 이용하여 별칭(alias)을 부여
# * 두 개 이상의 모듈에서 동일한 이름의 변수, 함수 클래스 등을 가져올 때 발생하는 이름 충돌 해결

# %%
from math import sqrt
from my_math import sqrt as my_sqrt

sqrt(4)     # math
my_sqrt(4)    # my_math

# %% [markdown]
# import *는 별개의 문제이다.
# * 이름 충돌은 as로 해결되지만, *는 무엇을 가져왔는지 코드에 적혀있지 않아 충돌이 일어나도 원인을 찾을 수 없다.
# * 에디터의 자동완성과 코드 검사 도구도 무력해진다.
# -> from은 자유롭게 쓰되 *하나만 피한다.

# %%
from math import *

e = 300    # math의 자연상수 e가 조용히 사라진다.

# %% [markdown]
# 사용자 정의 모듈

# %% [markdown]
# 직접 정의한 모듈 사용하기
# * my_math.py생성하여 두 수의 합을 구하는 add 함수를 작성한다.

# %%
# my_math.py
def add(x, y):
    return x + y

# %% [markdown]
# 같은 위치에 sample.py파일 생성하고 my_math 모듈의 add함수 import후 add함수 호출

# %%
# sample.py
import my_math

print(my_math.add(10, 20))    # 30
